# 167          bat         N             Rajasthan Royals    Wickets     5.0
# 170          bat         N  Royal Challengers Bangalore       Runs    37.0
# 171        field         N               Delhi Capitals       Runs    46.0
# 172          bat         N          Sunrisers Hyderabad       Runs    69.0
# 175        field         N               Delhi Capitals       Runs    59.0
# 176          bat         N          Chennai Super Kings    Wickets    10.0
# 177          bat         N               Mumbai Indians       Runs    34.0
# 179        field         N               Delhi Capitals       Runs    18.0
# 180          bat         N          Sunrisers Hyderabad       Runs     7.0
# 182        field         N        Kolkata Knight Riders       Runs    37.0
# 184        field         Y  Royal Challengers Bangalore  SuperOver     NaN
# 185        field         N             Rajasthan Royals    Wickets     4.0
# 187        field         N               Delhi Capitals       Runs    44.0
# 188        field         N              Kings XI Punjab       Runs    97.0
# 190        field         N             Rajasthan Royals       Runs    16.0
# 191        field         N  Royal Challengers Bangalore       Runs    10.0
# 192        field         Y               Delhi Capitals  SuperOver     NaN
# 532        field         N          Sunrisers Hyderabad       Runs    15.0
# 534        field         N              Kings XI Punjab    Wickets     5.0
# 535          bat         N          Chennai Super Kings    Wickets     5.0
# 536          bat         N             Delhi Daredevils    Wickets     6.0
# 539          bat         N          Sunrisers Hyderabad       Runs     4.0
# 540          bat         N          Chennai Super Kings    Wickets     7.0
# 541        field         N        Kolkata Knight Riders       Runs     2.0
# 542        field         N          Chennai Super Kings       Runs     7.0
# 543        field         N              Kings XI Punjab       Runs    72.0
# 545        field         N              Kings XI Punjab    Wickets     7.0
# 546          bat         N             Delhi Daredevils    Wickets     4.0
# 547        field         N  Royal Challengers Bangalore    Wickets     7.0
# 550        field         N  Royal Challengers Bangalore    Wickets     8.0
#
#     method Player_of_Match                                       Team1Players  \
# 134    NaN        TA Boult  ['MP Stoinis', 'S Dhawan', 'AM Rahane', 'SS Iy...
# 137    NaN       JJ Bumrah  ['Q de Kock', 'RG Sharma', 'SA Yadav', 'Ishan ...
# 138    NaN        S Nadeem  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 140    NaN      PJ Cummins  ['Shubman Gill', 'N Rana', 'RA Tripathi', 'SP ...
# 142    NaN    Ishan Kishan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 143    NaN  Sandeep Sharma  ['JR Philippe', 'D Padikkal', 'V Kohli', 'AB d...
# 145    NaN      RD Gaikwad  ['Shubman Gill', 'N Rana', 'SP Narine', 'RK Si...
# 147    NaN         WP Saha  ['DA Warner', 'WP Saha', 'MK Pandey', 'KS Will...
# 148    NaN        CH Gayle  ['Shubman Gill', 'N Rana', 'RA Tripathi', 'KD ...
# 150    NaN      RD Gaikwad  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 151    NaN       CJ Jordan  ['KL Rahul', 'Mandeep Singh', 'CH Gayle', 'N P...
# 153    NaN        TA Boult  ['RD Gaikwad', 'F du Plessis', 'AT Rayudu', 'N...
# 154    NaN       MK Pandey  ['RV Uthappa', 'BA Stokes', 'SV Samson', 'JC B...
# 156    NaN        S Dhawan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 159    NaN        KL Rahul  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 160    NaN  AB de Villiers  ['RV Uthappa', 'BA Stokes', 'SV Samson', 'SPD ...
# 161    NaN        S Dhawan  ['SM Curran', 'F du Plessis', 'SR Watson', 'AT...
# 163    NaN        KL Rahul  ['AJ Finch', 'D Padikkal', 'V Kohli', 'Washing...
# 164    NaN        A Nortje  ['PP Shaw', 'S Dhawan', 'AM Rahane', 'SS Iyer'...
# 165    NaN       RA Jadeja  ['SM Curran', 'F du Plessis', 'SR Watson', 'AT...
# 166    NaN  AB de Villiers  ['AJ Finch', 'D Padikkal', 'V Kohli', 'AB de V...
# 167    NaN       R Tewatia  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...
# 170    NaN         V Kohli  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 171    NaN        R Ashwin  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 172    NaN     JM Bairstow  ['DA Warner', 'JM Bairstow', 'Abdul Samad', 'M...
# 175    NaN        AR Patel  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 176    NaN       SR Watson  ['KL Rahul', 'MA Agarwal', 'Mandeep Singh', 'N...
# 177    NaN        TA Boult  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 179    NaN         SS Iyer  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 180    NaN         PK Garg  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...
# 182    NaN     Shivam Mavi  ['Shubman Gill', 'SP Narine', 'N Rana', 'AD Ru...
# 184    NaN  AB de Villiers  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 185    NaN       SV Samson  ['KL Rahul', 'MA Agarwal', 'GJ Maxwell', 'N Po...
# 187    NaN         PP Shaw  ['PP Shaw', 'S Dhawan', 'RR Pant', 'SS Iyer', ...
# 188    NaN        KL Rahul  ['KL Rahul', 'MA Agarwal', 'N Pooran', 'GJ Max...
# 190    NaN       SV Samson  ['YBK Jaiswal', 'SPD Smith', 'SV Samson', 'DA ...
# 191    NaN       YS Chahal  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...
# 192    NaN      MP Stoinis  ['PP Shaw', 'S Dhawan', 'SO Hetmyer', 'SS Iyer...
# 532    NaN         B Kumar  ['BR Dunk', 'RG Sharma', 'CJ Anderson', 'AT Ra...
# 534    NaN  Sandeep Sharma  ['CA Pujara', 'V Sehwag', 'WP Saha', 'GJ Maxwe...
# 535    NaN        DR Smith  ['AJ Finch', 'S Dhawan', 'DA Warner', 'KL Rahu...
# 536    NaN         M Vijay  ['Q de Kock', 'M Vijay', 'JP Duminy', 'KP Piet...
# 539    NaN        AJ Finch  ['S Dhawan', 'AJ Finch', 'DA Warner', 'KL Rahu...
# 540    NaN       MM Sharma  ['DR Smith', 'BB McCullum', 'SK Raina', 'F du ...
# 541    NaN         CA Lynn  ['PA Patel', 'YV Takawale', 'V Kohli', 'Yuvraj...
# 542    NaN       RA Jadeja  ['AM Nayar', 'AM Rahane', 'SV Samson', 'SR Wat...
# 543    NaN      GJ Maxwell  ['CA Pujara', 'V Sehwag', 'GJ Maxwell', 'DA Mi...
# 545    NaN      GJ Maxwell  ['AM Nayar', 'AM Rahane', 'SV Samson', 'SR Wat...
# 546    NaN       JP Duminy  ['JH Kallis', 'G Gambhir', 'MK Pandey', 'RV Ut...
# 547    NaN        PA Patel  ['NJ Maddinson', 'PA Patel', 'V Kohli', 'Yuvra...
# 550    NaN       YS Chahal  ['MA Agarwal', 'M Vijay', 'KD Karthik', 'MK Ti...
#
#                                           Team2Players                Umpire1  \
# 134  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...            CB Gaffaney
# 137  ['PP Shaw', 'S Dhawan', 'AM Rahane', 'SS Iyer'...            CB Gaffaney
# 138  ['DA Warner', 'WP Saha', 'MK Pandey', 'KS Will...          C Shamshuddin
# 140  ['RV Uthappa', 'BA Stokes', 'SPD Smith', 'SV S...            Nitin Menon
# 142  ['Ishan Kishan', 'Q de Kock', 'SA Yadav', 'SS ...               YC Barde
# 143  ['DA Warner', 'WP Saha', 'MK Pandey', 'KS Will...  KN Ananthapadmanabhan
# 145  ['SR Watson', 'RD Gaikwad', 'AT Rayudu', 'MS D...          C Shamshuddin
# 147  ['AM Rahane', 'S Dhawan', 'MP Stoinis', 'SO He...           AK Chaudhary
# 148  ['KL Rahul', 'Mandeep Singh', 'CH Gayle', 'N P...  KN Ananthapadmanabhan
# 150  ['RD Gaikwad', 'F du Plessis', 'AT Rayudu', 'M...          C Shamshuddin
# 151  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'Abd...            AY Dandekar
# 153  ['Q de Kock', 'Ishan Kishan', 'SA Yadav', 'SS ...          C Shamshuddin
# 154  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'V S...            Nitin Menon
# 156  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...          C Shamshuddin
# 159  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...            Nitin Menon
# 160  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...           AK Chaudhary
# 161  ['PP Shaw', 'S Dhawan', 'AM Rahane', 'SS Iyer'...  KN Ananthapadmanabhan
# 163  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...  KN Ananthapadmanabhan
# 164  ['BA Stokes', 'JC Buttler', 'SPD Smith', 'SV S...           AK Chaudhary
# 165  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...           AK Chaudhary
# 166  ['T Banton', 'Shubman Gill', 'N Rana', 'EJG Mo...         RK Illingworth
# 167  ['BA Stokes', 'JC Buttler', 'SPD Smith', 'SV S...               YC Barde
# 170  ['SR Watson', 'F du Plessis', 'AT Rayudu', 'N ...           AK Chaudhary
# 171  ['YBK Jaiswal', 'JC Buttler', 'SPD Smith', 'SV...  KN Ananthapadmanabhan
# 172  ['KL Rahul', 'MA Agarwal', 'P Simran Singh', '...           AK Chaudhary
# 175  ['D Padikkal', 'AJ Finch', 'V Kohli', 'AB de V...            Nitin Menon
# 176  ['SR Watson', 'F du Plessis', 'AT Rayudu', 'KM...            AY Dandekar
# 177  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...  KN Ananthapadmanabhan
# 179  ['Shubman Gill', 'SP Narine', 'N Rana', 'AD Ru...            VA Kulkarni
# 180  ['F du Plessis', 'SR Watson', 'AT Rayudu', 'KM...           AK Chaudhary
# 182  ['JC Buttler', 'SPD Smith', 'SV Samson', 'RV U...  KN Ananthapadmanabhan
# 184  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...            Nitin Menon
# 185  ['JC Buttler', 'SPD Smith', 'SV Samson', 'R Te...         RK Illingworth
# 187  ['M Vijay', 'SR Watson', 'F du Plessis', 'RD G...  KN Ananthapadmanabhan
# 188  ['D Padikkal', 'AJ Finch', 'JR Philippe', 'V K...           AK Chaudhary
# 190  ['M Vijay', 'SR Watson', 'F du Plessis', 'SM C...          C Shamshuddin
# 191  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'PK ...            AY Dandekar
# 192  ['KL Rahul', 'MA Agarwal', 'KK Nair', 'N Poora...           AK Chaudhary
# 532  ['AJ Finch', 'S Dhawan', 'KL Rahul', 'DA Warne...        HDPK Dharmasena
# 534  ['CH Gayle', 'PA Patel', 'V Kohli', 'YV Takawa...              BF Bowden
# 535  ['DR Smith', 'BB McCullum', 'SK Raina', 'MS Dh...           AK Chaudhary
# 536  ['RG Sharma', 'AP Tare', 'CJ Anderson', 'AT Ra...              Aleem Dar
# 539  ['Q de Kock', 'M Vijay', 'KP Pietersen', 'KD K...              M Erasmus
# 540  ['MEK Hussey', 'AP Tare', 'CJ Anderson', 'RG S...              BF Bowden
# 541  ['JH Kallis', 'G Gambhir', 'MK Pandey', 'CA Ly...              Aleem Dar
# 542  ['DR Smith', 'BB McCullum', 'SK Raina', 'F du ...        HDPK Dharmasena
# 543  ['AJ Finch', 'S Dhawan', 'DA Warner', 'KL Rahu...              M Erasmus
# 545  ['CA Pujara', 'V Sehwag', 'WP Saha', 'GJ Maxwe...              BF Bowden
# 546  ['M Vijay', 'MA Agarwal', 'KD Karthik', 'LRPL ...              Aleem Dar
# 547  ['MEK Hussey', 'AP Tare', 'AT Rayudu', 'RG Sha...              Aleem Dar
# 550  ['PA Patel', 'NJ Maddinson', 'V Kohli', 'Yuvra...              Aleem Dar
#
#             Umpire2
# 134     Nitin Menon
# 137     Nitin Menon
# 138  RK Illingworth
# 140      PR Reiffel
# 142      PR Reiffel
# 143    K Srinivasan
# 145  RK Illingworth
# 147     Nitin Menon
# 148  RK Illingworth
# 150  RK Illingworth
# 151      PR Reiffel
# 153     VA Kulkarni
# 154      PR Reiffel
# 156  RK Illingworth
# 159      PR Reiffel
# 160     Nitin Menon
# 161  RK Illingworth
# 163   C Shamshuddin
# 164     Nitin Menon
# 165      PR Reiffel
# 166    K Srinivasan
# 167      PR Reiffel
# 170      PR Reiffel
# 171   C Shamshuddin
# 172     Nitin Menon
# 175        YC Barde
# 176     Nitin Menon
# 177  RK Illingworth
# 179  RK Illingworth
# 180      PR Reiffel
# 182   C Shamshuddin
# 184      PR Reiffel
# 185    K Srinivasan
# 187  RK Illingworth
# 188      PR Reiffel
# 190     VA Kulkarni
# 191     Nitin Menon
# 192     Nitin Menon
# 532       M Erasmus
# 534          S Ravi
# 535     VA Kulkarni
# 536     VA Kulkarni
# 539          S Ravi
# 540       M Erasmus
# 541     VA Kulkarni
# 542  RK Illingworth
# 543          S Ravi
# 545       M Erasmus
# 546     VA Kulkarni
# 547    AK Chaudhary
# 550          S Ravi

# %%
file1['City'] = file1.apply(lambda row: 'Sharjah' if row['Venue'] == 'Sharjah Cricket Stadium' else row['City'], axis=1)

# %%
file1['City'] = file1.apply(lambda row: 'Dubai' if row['Venue'] == 'Dubai International Cricket Stadium' else row['City'], axis=1)

# %%
file1['City'].unique()
# Out:
# array(['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
#        'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai', 'Hyderabad',
#        'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
#        'Bangalore', 'Kanpur', 'Rajkot', 'Raipur', 'Ranchi', 'Cuttack',
#        'Dharamsala', 'Kochi', 'Nagpur', 'Johannesburg', 'Centurion',
#        'Durban', 'Bloemfontein', 'Port Elizabeth', 'Kimberley',
#        'East London', 'Cape Town'], dtype=object)

# %%
file1['City'].replace({'Johannesburg':'Others', 'Bloemfontein':'Others', 'Port Elizabeth':'Others', 'Kimberley':'Others',
       'East London':'Others', 'Cape Town':'Others','Rajkot':'Others','Indore':'Others','Navi Mumbai':'Others','Dharamsala':'Others','Ranchi':'Others','Cuttack':'Others','Raipur':'Others','Kochi':'Others','Kanpur':'Others','Nagpur':'Others','Bengaluru':'Bangalore'},inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11324\2066369866.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   file1['City'].replace({'Johannesburg':'Others', 'Bloemfontein':'Others', 'Port Elizabeth':'Others', 'Kimberley':'Others',

# %%
file1['City'].value_counts()
# Out:
# City
# Mumbai           159
# Others            99
# Bangalore         80
# Kolkata           79
# Delhi             78
# Chennai           67
# Hyderabad         64
# Chandigarh        56
# Pune              51
# Jaipur            47
# Dubai             46
# Abu Dhabi         37
# Sharjah           28
# Ahmedabad         19
# Durban            15
# Visakhapatnam     13
# Centurion         12
# Name: count, dtype: int64

# %%
file1.isnull().sum()
# Out:
# ID                   0
# City                 0
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
file1['Margin'].fillna(value=0,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11324\1559389999.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   file1['Margin'].fillna(value=0,inplace=True)

# %%
file1.drop(['method'],axis=1,inplace=True)

# %%
file1.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          4
# WinningTeam        4
# WonBy              0
# Margin             0
# Player_of_Match    4
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
file1.dropna(subset='WinningTeam',inplace=True)

# %%
file1['Date'] = pd.to_datetime(file1['Date'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11324\649345398.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   file1['Date'] = pd.to_datetime(file1['Date'])

# %%
file1['Margin'] = file1['Margin'].astype(int)
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 946 entries, 0 to 949
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               946 non-null    int64
#  1   City             946 non-null    object
#  2   Date             946 non-null    datetime64[ns]
#  3   Season           946 non-null    object
#  4   MatchNumber      946 non-null    object
#  5   Team1            946 non-null    object
#  6   Team2            946 non-null    object
#  7   Venue            946 non-null    object
#  8   TossWinner       946 non-null    object
#  9   TossDecision     946 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            946 non-null    object
#  13  Margin           946 non-null    int32
#  14  Player_of_Match  946 non-null    object
#  15  Team1Players     946 non-null    object
#  16  Team2Players     946 non-null    object
#  17  Umpire1          946 non-null    object
#  18  Umpire2          946 non-null    object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(16)
# memory usage: 144.1+ KB

# %%
file1['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
file1['Team1'] = file1['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
file1['Team1'] = file1['Team1'].str.replace('Gujarat Lions','Gujarat Titans')
file1['Team1'] = file1['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
file1['Team1'] = file1['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
file1.loc[file1['Team1'].isin(['Rising Pune Supergiant','Rising Pune Supergiants']),'Team1'] = 'Rising Pune Supergiants'
file1['Team1'] = file1['Team1'].str.replace('Rising Pune Supergiants','Pune Warriors')

# %%
file1['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Pune Warriors',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
file1['Team2'].unique()
# Out:
# array(['Gujarat Titans', 'Rajasthan Royals', 'Lucknow Super Giants',
#        'Punjab Kings', 'Mumbai Indians', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad', 'Delhi Capitals',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
file1['Team2'] = file1['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')
file1['Team2'] = file1['Team2'].str.replace('Gujarat Lions','Gujarat Titans')
file1['Team2'] = file1['Team2'].str.replace('Kings XI Punjab','Punjab Kings')
file1['Team2'] = file1['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
file1.loc[file1['Team2'].isin(['Rising Pune Supergiant','Rising Pune Supergiants']),'Team2'] = 'Rising Pune Supergiants'
file1['Team2'] = file1['Team2'].str.replace('Rising Pune Supergiants','Pune Warriors')

# %%
file1['Team2'].unique()
# Out:
# array(['Gujarat Titans', 'Rajasthan Royals', 'Lucknow Super Giants',
#        'Punjab Kings', 'Mumbai Indians', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad', 'Delhi Capitals',
#        'Chennai Super Kings', 'Pune Warriors', 'Kochi Tuskers Kerala'],
#       dtype=object)

# %%
file1['TossWinner'].unique()
# Out:
# array(['Rajasthan Royals', 'Lucknow Super Giants', 'Gujarat Titans',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Chennai Super Kings',
#        'Punjab Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Delhi Capitals', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
file1['TossWinner'] = file1['TossWinner'].str.replace('Delhi Daredevils','Delhi Capitals')
file1['TossWinner'] = file1['TossWinner'].str.replace('Gujarat Lions','Gujarat Titans')
file1['TossWinner'] = file1['TossWinner'].str.replace('Kings XI Punjab','Punjab Kings')
file1['TossWinner'] = file1['TossWinner'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
file1.loc[file1['TossWinner'].isin(['Rising Pune Supergiant','Rising Pune Supergiants']),'TossWinner'] = 'Rising Pune Supergiants'
file1['TossWinner'] = file1['TossWinner'].str.replace('Rising Pune Supergiants','Pune Warriors')

# %%
file1['WinningTeam'].unique()
# Out:
# array(['Gujarat Titans', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Punjab Kings', 'Mumbai Indians',
#        'Lucknow Super Giants', 'Sunrisers Hyderabad', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Chennai Super Kings', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
file1['WinningTeam'] = file1['WinningTeam'].str.replace('Delhi Daredevils','Delhi Capitals')
file1['WinningTeam'] = file1['WinningTeam'].str.replace('Gujarat Lions','Gujarat Titans')
file1['WinningTeam'] = file1['WinningTeam'].str.replace('Kings XI Punjab','Punjab Kings')
file1['WinningTeam'] = file1['WinningTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
file1.loc[file1['WinningTeam'].isin(['Rising Pune Supergiant','Rising Pune Supergiants']),'WinningTeam'] = 'Rising Pune Supergiants'
file1['WinningTeam'] = file1['WinningTeam'].str.replace('Rising Pune Supergiants','Pune Warriors')

# %%
#file1['Venue'].unique()

# %%
file1.loc[file1['Venue'].isin(['Narendra Modi Stadium, Ahmedabad','Sardar Patel Stadium, Motera']),'Venue'] = 'Narendra Modi Stadium, Ahmedabad'
file1.loc[file1['Venue'].isin(['Eden Gardens, Kolkata','Eden Gardens']),'Venue'] = 'Eden Gardens, Kolkata'
file1.loc[file1['Venue'].isin(['Wankhede Stadium, Mumbai','Wankhede Stadium']),'Venue'] = 'Wankhede Stadium, Mumbai'
file1.loc[file1['Venue'].isin(['Brabourne Stadium, Mumbai','Brabourne Stadium']),'Venue'] = 'Brabourne Stadium, Mumbai'
file1.loc[file1['Venue'].isin(['Dr DY Patil Sports Academy, Mumbai','Dr DY Patil Sports Academy']),'Venue'] = 'Dr DY Patil Sports Academy, Mumbai'
file1.loc[file1['Venue'].isin(['Zayed Cricket Stadium, Abu Dhabi','Sheikh Zayed Stadium']),'Venue'] = 'Zayed Cricket Stadium, Abu Dhabi'
file1.loc[file1['Venue'].isin(['Arun Jaitley Stadium, Delhi','Arun Jaitley Stadium','Feroz Shah Kotla']),'Venue'] = 'Arun Jaitley Stadium, Delhi'
file1.loc[file1['Venue'].isin(['MA Chidambaram Stadium, Chepauk, Chennai','MA Chidambaram Stadium','MA Chidambaram Stadium, Chepauk']),'Venue'] = 'MA Chidambaram Stadium, Chepauk, Chennai'
file1.loc[file1['Venue'].isin(['Rajiv Gandhi International Stadium, Uppal','Rajiv Gandhi International Stadium']),'Venue'] = 'Rajiv Gandhi International Stadium, Uppal'
file1.loc[file1['Venue'].isin(['Punjab Cricket Association IS Bindra Stadium, Mohali','Punjab Cricket Association IS Bindra Stadium','Punjab Cricket Association Stadium, Mohali']),'Venue'] = 'Punjab Cricket Association Stadium, Mohali'
file1.loc[file1['Venue'].isin(['M.Chinnaswamy Stadium','M Chinnaswamy Stadium']),'Venue'] = 'M Chinnaswamy Stadium'

# %%
file1['Venue'].unique()
# Out:
# array(['Narendra Modi Stadium, Ahmedabad', 'Eden Gardens, Kolkata',
#        'Wankhede Stadium, Mumbai', 'Brabourne Stadium, Mumbai',
#        'Dr DY Patil Sports Academy, Mumbai',
#        'Maharashtra Cricket Association Stadium, Pune',
#        'Dubai International Cricket Stadium', 'Sharjah Cricket Stadium',
#        'Zayed Cricket Stadium, Abu Dhabi', 'Arun Jaitley Stadium, Delhi',
#        'MA Chidambaram Stadium, Chepauk, Chennai',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Punjab Cricket Association Stadium, Mohali',
#        'M Chinnaswamy Stadium', 'Sawai Mansingh Stadium',
#        'Maharashtra Cricket Association Stadium',
#        'Holkar Cricket Stadium', 'Green Park',
#        'Saurashtra Cricket Association Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Barabati Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'New Wanderers Stadium', 'SuperSport Park', 'Kingsmead',
#        'OUTsurance Oval', "St George's Park", 'De Beers Diamond Oval',
#        'Buffalo Park', 'Newlands'], dtype=object)

# %% [markdown]
# file1.head()
# file1.info()

# %%
file1['Team1Players'] = file1['Team1Players'].apply(lambda x: x.split(','))

file1 = file1.join(pd.DataFrame(file1['Team1Players'].to_list(), columns=['T1_P1', 'T1_P2', 'T1_P3','T1_P4','T1_P5','T1_P6','T1_P7','T1_P8','T1_P9','T1_P10','T1_P11']))
file1
# Out:
#           ID        City       Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad 2022-05-29     2022        Final
# 1    1312199   Ahmedabad 2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata 2022-05-25     2022   Eliminator
# 3    1312197     Kolkata 2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai 2022-05-22     2022           70
# ..       ...         ...        ...      ...          ...
# 945   335986     Kolkata 2008-04-20  2007/08            4
# 946   335985      Mumbai 2008-04-20  2007/08            5
# 947   335984       Delhi 2008-04-19  2007/08            3
# 948   335983  Chandigarh 2008-04-19  2007/08            2
# 949   335982   Bangalore 2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders          Sunrisers Hyderabad
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947               Delhi Capitals             Rajasthan Royals
# 948                 Punjab Kings          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                       Eden Gardens, Kolkata          Sunrisers Hyderabad
# 946                    Wankhede Stadium, Mumbai               Mumbai Indians
# 947                 Arun Jaitley Stadium, Delhi             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...               T1_P2           T1_P3          T1_P4  \
# 0            bat  ...        'JC Buttler'     'SV Samson'   'D Padikkal'
# 1          field  ...      'F du Plessis'    'RM Patidar'   'GJ Maxwell'
# 2          field  ...      'F du Plessis'    'RM Patidar'   'GJ Maxwell'
# 3          field  ...        'JC Buttler'     'SV Samson'   'D Padikkal'
# 4            bat  ...   'Abhishek Sharma'   'RA Tripathi'   'AK Markram'
# ..           ...  ...                 ...             ...            ...
# 945          bat  ...          'W Jaffer'       'V Kohli'    'JH Kallis'
# 946          bat  ...                 NaN             NaN            NaN
# 947          bat  ...                 NaN             NaN            NaN
# 948          bat  ...                 NaN             NaN            NaN
# 949        field  ...                 NaN             NaN            NaN
#
#              T1_P5                 T1_P6             T1_P7            T1_P8  \
# 0     'SO Hetmyer'            'R Ashwin'         'R Parag'       'TA Boult'
# 1      'MK Lomror'          'KD Karthik'   'Shahbaz Ahmed'   'PWH de Silva'
# 2      'MK Lomror'          'KD Karthik'   'Shahbaz Ahmed'       'HV Patel'
# 3     'SO Hetmyer'             'R Parag'        'R Ashwin'       'TA Boult'
# 4       'N Pooran'   'Washington Sundar'      'R Shepherd'      'J Suchith'
# ..             ...                   ...               ...              ...
# 945     'CL White'          'MV Boucher'         'B Akhil'      'AA Noffke'
# 946            NaN                   NaN               NaN              NaN
# 947            NaN                   NaN               NaN              NaN
# 948            NaN                   NaN               NaN              NaN
# 949            NaN                   NaN               NaN              NaN
#
#                T1_P9                T1_P10                T1_P11
# 0         'OC McCoy'   'M Prasidh Krishna'          'YS Chahal']
# 1         'HV Patel'        'JR Hazlewood'     'Mohammed Siraj']
# 2     'PWH de Silva'        'JR Hazlewood'     'Mohammed Siraj']
# 3        'YS Chahal'   'M Prasidh Krishna'           'OC McCoy']
# 4          'B Kumar'         'Umran Malik'   'Fazalhaq Farooqi']
# ..               ...                   ...                   ...
# 945        'P Kumar'              'Z Khan'           'SB Joshi']
# 946              NaN                   NaN                   NaN
# 947              NaN                   NaN                   NaN
# 948              NaN                   NaN                   NaN
# 949              NaN                   NaN                   NaN
#
# [946 rows x 30 columns]

# %%
file1['T1_P11'] = file1['T1_P11'].str.replace(']',"")
file1['T1_P1'] = file1['T1_P1'].str.replace('[',"")
file1['T1_P11'] = file1['T1_P11'].str.replace("'","")
file1['T1_P10'] = file1['T1_P10'].str.replace("'","")
file1['T1_P9'] = file1['T1_P9'].str.replace("'","")
file1['T1_P8'] = file1['T1_P8'].str.replace("'","")
file1['T1_P7'] = file1['T1_P7'].str.replace("'","")
file1['T1_P6'] = file1['T1_P6'].str.replace("'","")
file1['T1_P5'] = file1['T1_P5'].str.replace("'","")
file1['T1_P4'] = file1['T1_P4'].str.replace("'","")
file1['T1_P3'] = file1['T1_P3'].str.replace("'","")
file1['T1_P2'] = file1['T1_P2'].str.replace("'","")
file1['T1_P1'] = file1['T1_P1'].str.replace("'","")

file1
# Out:
#           ID        City       Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad 2022-05-29     2022        Final
# 1    1312199   Ahmedabad 2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata 2022-05-25     2022   Eliminator
# 3    1312197     Kolkata 2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai 2022-05-22     2022           70
# ..       ...         ...        ...      ...          ...
# 945   335986     Kolkata 2008-04-20  2007/08            4
# 946   335985      Mumbai 2008-04-20  2007/08            5
# 947   335984       Delhi 2008-04-19  2007/08            3
# 948   335983  Chandigarh 2008-04-19  2007/08            2
# 949   335982   Bangalore 2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders          Sunrisers Hyderabad
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947               Delhi Capitals             Rajasthan Royals
# 948                 Punjab Kings          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                       Eden Gardens, Kolkata          Sunrisers Hyderabad
# 946                    Wankhede Stadium, Mumbai               Mumbai Indians
# 947                 Arun Jaitley Stadium, Delhi             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...             T1_P2         T1_P3        T1_P4  \
# 0            bat  ...        JC Buttler     SV Samson   D Padikkal
# 1          field  ...      F du Plessis    RM Patidar   GJ Maxwell
# 2          field  ...      F du Plessis    RM Patidar   GJ Maxwell
# 3          field  ...        JC Buttler     SV Samson   D Padikkal
# 4            bat  ...   Abhishek Sharma   RA Tripathi   AK Markram
# ..           ...  ...               ...           ...          ...
# 945          bat  ...          W Jaffer       V Kohli    JH Kallis
# 946          bat  ...               NaN           NaN          NaN
# 947          bat  ...               NaN           NaN          NaN
# 948          bat  ...               NaN           NaN          NaN
# 949        field  ...               NaN           NaN          NaN
#
#            T1_P5               T1_P6           T1_P7          T1_P8  \
# 0     SO Hetmyer            R Ashwin         R Parag       TA Boult
# 1      MK Lomror          KD Karthik   Shahbaz Ahmed   PWH de Silva
# 2      MK Lomror          KD Karthik   Shahbaz Ahmed       HV Patel
# 3     SO Hetmyer             R Parag        R Ashwin       TA Boult
# 4       N Pooran   Washington Sundar      R Shepherd      J Suchith
# ..           ...                 ...             ...            ...
# 945     CL White          MV Boucher         B Akhil      AA Noffke
# 946          NaN                 NaN             NaN            NaN
# 947          NaN                 NaN             NaN            NaN
# 948          NaN                 NaN             NaN            NaN
# 949          NaN                 NaN             NaN            NaN
#
#              T1_P9              T1_P10             T1_P11
# 0         OC McCoy   M Prasidh Krishna          YS Chahal
# 1         HV Patel        JR Hazlewood     Mohammed Siraj
# 2     PWH de Silva        JR Hazlewood     Mohammed Siraj
# 3        YS Chahal   M Prasidh Krishna           OC McCoy
# 4          B Kumar         Umran Malik   Fazalhaq Farooqi
# ..             ...                 ...                ...
# 945        P Kumar              Z Khan           SB Joshi
# 946            NaN                 NaN                NaN
# 947            NaN                 NaN                NaN
# 948            NaN                 NaN                NaN
# 949            NaN                 NaN                NaN
#
# [946 rows x 30 columns]

# %%
file1['Team2Players'] = file1['Team2Players'].apply(lambda x: x.split(','))

file1 = file1.join(pd.DataFrame(file1['Team2Players'].to_list(), columns=['T2_P1', 'T2_P2', 'T2_P3','T2_P4','T2_P5','T2_P6','T2_P7','T2_P8','T2_P9','T2_P10','T2_P11']))

# %%
file1['T2_P11'] = file1['T2_P11'].str.replace(']','')
file1['T2_P1'] = file1['T2_P1'].str.replace('[','')
file1['T2_P11'] = file1['T2_P11'].str.replace("'","")
file1['T2_P10'] = file1['T2_P10'].str.replace("'","")
file1['T2_P9'] = file1['T2_P9'].str.replace("'","")
file1['T2_P8'] = file1['T2_P8'].str.replace("'","")
file1['T2_P7'] = file1['T2_P7'].str.replace("'","")
file1['T2_P6'] = file1['T2_P6'].str.replace("'","")
file1['T2_P5'] = file1['T2_P5'].str.replace("'","")
file1['T2_P4'] = file1['T2_P4'].str.replace("'","")
file1['T2_P3'] = file1['T2_P3'].str.replace("'","")
file1['T2_P2'] = file1['T2_P2'].str.replace("'","")
file1['T2_P1'] = file1['T2_P1'].str.replace("'","")

# %%
IPL_Dataset = file1[['ID','Team1','Team2','City','TossWinner','WonBy','TossDecision','WinningTeam','T1_P1','T1_P2','T1_P3','T1_P4','T1_P5','T1_P6','T1_P7','T1_P8','T1_P9','T1_P10','T1_P11','T2_P1','T2_P2','T2_P3','T2_P4','T2_P5','T2_P6','T2_P7','T2_P8','T2_P9','T2_P10','T2_P11']].copy()
IPL_Dataset
# Out:
#           ID                        Team1                        Team2  \
# 0    1312200             Rajasthan Royals               Gujarat Titans
# 1    1312199  Royal Challengers Bangalore             Rajasthan Royals
# 2    1312198  Royal Challengers Bangalore         Lucknow Super Giants
# 3    1312197             Rajasthan Royals               Gujarat Titans
# 4    1304116          Sunrisers Hyderabad                 Punjab Kings
# ..       ...                          ...                          ...
# 945   335986        Kolkata Knight Riders          Sunrisers Hyderabad
# 946   335985               Mumbai Indians  Royal Challengers Bangalore
# 947   335984               Delhi Capitals             Rajasthan Royals
# 948   335983                 Punjab Kings          Chennai Super Kings
# 949   335982  Royal Challengers Bangalore        Kolkata Knight Riders
#
#            City                   TossWinner    WonBy TossDecision  \
# 0     Ahmedabad             Rajasthan Royals  Wickets          bat
# 1     Ahmedabad             Rajasthan Royals  Wickets        field
# 2       Kolkata         Lucknow Super Giants     Runs        field
# 3       Kolkata               Gujarat Titans  Wickets        field
# 4        Mumbai          Sunrisers Hyderabad  Wickets          bat
# ..          ...                          ...      ...          ...
# 945     Kolkata          Sunrisers Hyderabad  Wickets          bat
# 946      Mumbai               Mumbai Indians  Wickets          bat
# 947       Delhi             Rajasthan Royals  Wickets          bat
# 948  Chandigarh          Chennai Super Kings     Runs          bat
# 949   Bangalore  Royal Challengers Bangalore     Runs        field
#
#                      WinningTeam        T1_P1             T1_P2  ...  \
# 0                 Gujarat Titans  YBK Jaiswal        JC Buttler  ...
# 1               Rajasthan Royals      V Kohli      F du Plessis  ...
# 2    Royal Challengers Bangalore      V Kohli      F du Plessis  ...
# 3                 Gujarat Titans  YBK Jaiswal        JC Buttler  ...
# 4                   Punjab Kings      PK Garg   Abhishek Sharma  ...
# ..                           ...          ...               ...  ...
# 945        Kolkata Knight Riders     R Dravid          W Jaffer  ...
# 946  Royal Challengers Bangalore          NaN               NaN  ...
# 947               Delhi Capitals          NaN               NaN  ...
# 948          Chennai Super Kings          NaN               NaN  ...
# 949        Kolkata Knight Riders          NaN               NaN  ...
#
#              T2_P2             T2_P3        T2_P4             T2_P5  \
# 0     Shubman Gill           MS Wade    HH Pandya         DA Miller
# 1       JC Buttler         SV Samson   D Padikkal        SO Hetmyer
# 2         KL Rahul           M Vohra     DJ Hooda        MP Stoinis
# 3     Shubman Gill           MS Wade    HH Pandya         DA Miller
# 4         S Dhawan   M Shahrukh Khan   MA Agarwal    LS Livingstone
# ..             ...               ...          ...               ...
# 945    BB McCullum        RT Ponting    DJ Hussey   Mohammad Hafeez
# 946            NaN               NaN          NaN               NaN
# 947            NaN               NaN          NaN               NaN
# 948            NaN               NaN          NaN               NaN
# 949            NaN               NaN          NaN               NaN
#
#           T2_P6         T2_P7           T2_P8         T2_P9  \
# 0     R Tewatia   Rashid Khan   R Sai Kishore   LH Ferguson
# 1       R Parag      R Ashwin        TA Boult     YS Chahal
# 2       E Lewis     KH Pandya    PVD Chameera   Mohsin Khan
# 3     R Tewatia   Rashid Khan   R Sai Kishore     AS Joseph
# 4     JM Sharma     PN Mankad   Harpreet Brar      K Rabada
# ..          ...           ...             ...           ...
# 945   LR Shukla       WP Saha      AB Agarkar      AB Dinda
# 946         NaN           NaN             NaN           NaN
# 947         NaN           NaN             NaN           NaN
# 948         NaN           NaN             NaN           NaN
# 949         NaN           NaN             NaN           NaN
#
#                  T2_P10           T2_P11
# 0            Yash Dayal   Mohammed Shami
# 1     M Prasidh Krishna         OC McCoy
# 2            Avesh Khan     Ravi Bishnoi
# 3            Yash Dayal   Mohammed Shami
# 4              NT Ellis   Arshdeep Singh
# ..                  ...              ...
# 945            M Kartik         I Sharma
# 946                 NaN              NaN
# 947                 NaN              NaN
# 948                 NaN              NaN
# 949                 NaN              NaN
#
# [946 rows x 30 columns]
